# %% [markdown]
# <a href="https://colab.research.google.com/github/AnithaN21/AI-12-days-Bootcamp/blob/main/Day10_10A_MultiAgent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q "numpy<2.0"
# !pip install -q --upgrade crewai litellm google-generativeai google-genai
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 1.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 52.9 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# rasterio 1.5.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# shap 0.51.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# tobler 0.14.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# pytensor 2.38.3 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-contrib-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# tifffile 2026.4.11 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# xarray-einstats 0.10.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-python-headless 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# jax 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.7/52.7 kB 3.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.5/89.5 kB 8.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 3.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 kB 3.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 4.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.4/68.4 kB 6.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 976.4/976.4 kB 21.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.5/111.5 kB 10.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.0/17.0 MB 70.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 822.5/822.5 kB 45.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.9/19.9 MB 57.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 9.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.1/278.1 kB 20.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 246.1/246.1 kB 15.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.2/178.2 kB 11.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.9/46.9 MB 12.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.6/233.6 kB 16.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.8/65.8 kB 5.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.7/55.7 kB 4.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.5/118.5 kB 10.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.2/196.2 kB 16.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 5.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 102.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.2/45.2 kB 4.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 803.6/803.6 kB 49.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 23.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 360.7/360.7 kB 26.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 83.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 334.8/334.8 kB 24.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 62.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 9.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.6/71.6 kB 6.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 76.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 5.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.1/731.1 kB 41.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 310.5/310.5 kB 23.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.3/122.3 kB 11.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.9/24.9 MB 18.3 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires google-auth==2.47.0, but you have google-auth 2.53.0 which is incompatible.
# opentelemetry-exporter-gcp-logging 1.11.0a0 requires opentelemetry-api>=1.35.0, but you have opentelemetry-api 1.34.1 which is incompatible.
# opentelemetry-exporter-gcp-logging 1.11.0a0 requires opentelemetry-sdk<1.39.0,>=1.35.0, but you have opentelemetry-sdk 1.34.1 which is incompatible.
# rasterio 1.5.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# google-adk 1.29.0 requires google-genai<2.0.0,>=1.64.0, but you have google-genai 2.7.0 which is incompatible.
# google-adk 1.29.0 requires opentelemetry-api<1.39.0,>=1.36.0, but you have opentelemetry-api 1.34.1 which is incompatible.
# google-adk 1.29.0 requires opentelemetry-exporter-otlp-proto-http>=1.36.0, but you have opentelemetry-exporter-otlp-proto-http 1.34.1 which is incompatible.
# google-adk 1.29.0 requires opentelemetry-sdk<1.39.0,>=1.36.0, but you have opentelemetry-sdk 1.34.1 which is incompatible.
# tobler 0.14.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# wandb 0.27.0 requires click>=8.2.0, but you have click 8.1.8 which is incompatible.
# bigframes 2.40.0 requires rich<14,>=12.4.4, but you have rich 14.3.4 which is incompatible.

# %%
import os, getpass

os.environ["GEMINI_API_KEY"] = getpass.getpass("Enter Gemini API Key: ")

print("API key set")
# Out:
# Enter Gemini API Key: ··········
# API key set

# %%
from crewai import Agent, Task, Crew, Process

print("CrewAI imported successfully")
# Out:
# 05:32:37 - LiteLLM:WARNING: common_utils.py:979 - litellm: could not pre-load bedrock-runtime response stream shape — Bedrock event-stream decoding will be unavailable. Error: No module named 'botocore'
# WARNING:LiteLLM:litellm: could not pre-load bedrock-runtime response stream shape — Bedrock event-stream decoding will be unavailable. Error: No module named 'botocore'
# 05:32:37 - LiteLLM:WARNING: common_utils.py:24 - litellm: could not pre-load sagemaker-runtime response stream shape — SageMaker event-stream decoding will be unavailable. Error: No module named 'botocore'
# WARNING:LiteLLM:litellm: could not pre-load sagemaker-runtime response stream shape — SageMaker event-stream decoding will be unavailable. Error: No module named 'botocore'
# CrewAI imported successfully

# %%
llm = "gemini/gemini-2.5-flash"

print(llm)
# Out:
# gemini/gemini-2.5-flash

# %%
researcher = Agent(
    role="Placement Researcher",
    goal="Compile concise, factual placement-prep notes for B.Tech students",
    backstory="You are a research analyst who prepares short factual placement briefs in bullet form.",
    llm=llm,
    verbose=True,
    allow_delegation=False,
)

print("Researcher agent created")
# Out:
# Researcher agent created

# %%
writer = Agent(
    role="Placement Brief Writer",
    goal="Convert research notes into a clean 1-page placement brief in markdown",
    backstory="You write clear student-friendly placement briefs with headings and actionable takeaways.",
    llm=llm,
    verbose=True,
    allow_delegation=False,
)

print("Writer agent created")
# Out:
# Writer agent created

# %%
research_task = Task(
    description=(
        "Research TCS Digital placement preparation for B.Tech students. "
        "Include hiring process, technical stack, eligibility, recent hiring trends, "
        "and preparation tips. Give 3-5 bullets per section."
    ),
    agent=researcher,
    expected_output=(
        "Markdown bullet list with 5 sections: Hiring Process, Technical Stack, "
        "Eligibility, Recent Hiring Trends, Prep Tips."
    ),
)

print("Research task created")
# Out:
# Research task created

# %%
write_task = Task(
    description=(
        "Using the research notes, produce a 1-page placement brief for B.Tech students. "
        "Use markdown format. Include a 3-line opening hook, 5 clear sections, "
        "and a 3-line closing call-to-action."
    ),
    agent=writer,
    expected_output='1-page markdown brief titled "TCS Digital — Placement Prep Brief".',
)

print("Writer task created")
# Out:
# Writer task created

# %%
crew = Crew(
    agents=[researcher, writer],
    tasks=[research_task, write_task],
    process=Process.sequential,
    verbose=True,
)

print("Crew created successfully")
# Out:
# Crew created successfully

# %%
result = await crew.kickoff_async()

print("\n\n=== FINAL OUTPUT ===\n")
print(result)
# Out:
# ╭─────────────────────────────────────────── 🚀 Crew Execution Started ───────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: 209563b7-2543-489e-b6d8-85f8c55cc9db                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Research TCS Digital placement preparation for B.Tech students. Include hiring process, technical        │
# │  stack, eligibility, recent hiring trends, and preparation tips. Give 3-5 bullets per section.                  │
# │  ID: 126a98fd-6f7c-4fed-921b-81d1079648a2                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Researcher                                                                                    │
# │                                                                                                                 │
# │  Task: Research TCS Digital placement preparation for B.Tech students. Include hiring process, technical        │
# │  stack, eligibility, recent hiring trends, and preparation tips. Give 3-5 bullets per section.                  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [Finalize] todos_count=0, todos_with_results=0
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Researcher                                                                                    │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Here is a factual placement brief for TCS Digital preparation for B.Tech students:                             │
# │                                                                                                                 │
# │  ### Hiring Process                                                                                             │
# │                                                                                                                 │
# │  *   **Online Assessment:** Consists of verbal ability, logical reasoning, numerical ability, and advanced      │
# │  coding sections. The coding challenge is significantly more difficult than for TCS Ninja.                      │
# │  *   **Technical Interview:** Focuses on in-depth Data Structures & Algorithms (DSA), core CS concepts          │
# │  (Operating Systems, DBMS, OOPS, Computer Networks), chosen programming language proficiency, and detailed      │
# │  discussion of projects. Problem-solving skills are critically evaluated.                                       │
# │  *   **Managerial Interview (Optional/Combined):** May assess situational judgment, leadership potential, and   │
# │  technical vision relevant to complex project scenarios, often combined with the technical round.               │
# │  *   **HR Interview:** Standard HR questions, background verification, salary expectations, and assessment of   │
# │  cultural fit and communication skills.                                                                         │
# │                                                                                                                 │
# │  ### Technical Stack                                                                                            │
# │                                                                                                                 │
# │  *   **Core Programming Languages:** Proficiency in at least one modern language like Java, Python, or C++ is   │
# │  essential, with a strong grasp of OOPS principles.                                                             │
# │  *   **Data Structures & Algorithms (DSA):** A fundamental and critical requirement for problem-solving across  │
# │  various technical domains.                                                                                     │
# │  *   **Database Management:** Strong knowledge of SQL (e.g., MySQL, PostgreSQL, Oracle) and an understanding    │
# │  of NoSQL database concepts.                                                                                    │
# │  *   **Web Technologies/Frameworks:** Familiarity with front-end frameworks (e.g., React, Angular) or back-end  │
# │  frameworks (e.g., Spring Boot, Django, Flask) is a significant advantage.                                      │
# │  *   **Cloud Computing/DevOps Concepts:** Exposure to platforms like AWS, Azure, GCP, or concepts like CI/CD,   │
# │  microservices architecture, and containerization (Docker, Kubernetes) is highly valued.                        │
# │                                                                                                                 │
# │  ### Eligibility                                                                                                │
# │                                                                                                                 │
# │  *   **Degree:** B.E./B.Tech graduates from all engineering disciplines, with a strong preference for Computer  │
# │  Science, Information Technology, Electronics & Communication Engineering, and Electrical Engineering.          │
# │  *   **Academic Performance:** Consistent academic record with typically 60% or 6.0 CGPA throughout 10th,       │
# │  12th, and B.Tech.                                                                                              │
# │  *   **Backlogs:** No active backlogs are usually permitted at the time of appearing for the process or         │
# │  joining.                                                                                                       │
# │  *   **Education Gap:** Generally, no more than 1-2 years gap in education is allowed, with no prior work       │
# │  experience for freshers.                                                                                       │
# │                                                                                                                 │
# │  ### Recent Hiring Trends                                                                                       │
# │                                                                                                                 │
# │  *   **Increased Focus on Niche Skills:** Strong demand for candidates proficient in specialized areas like     │
# │  Artificial Intelligence/Machine Learning, Data Science, Cloud Computing, Cybersecurity, and IoT.               │
# │  *   **Practical Coding & Project Experience:** Greater emphasis on demonstrating actual coding ability and     │
# │  showcasing impactful, real-world projects over theoretical knowledge alone.                                    │
# │  *   **Higher Compensation:** TCS Digital offers significantly higher compensation packages compared to TCS     │
# │  Ninja, reflecting the demand for specialized, high-skill talent.                                               │
# │  *   **Problem-Solving Acumen:** Hiring prioritizes candidates who can demonstrate strong analytical, critical  │
# │  thinking, and structured problem-solving skills to tackle complex business challenges.                         │
# │                                                                                                                 │
# │  ### Prep Tips                                                                                                  │
# │                                                                                                                 │
# │  *   **Master DSA & Coding:** Dedicate significant time to practicing Data Structures and Algorithms on         │
# │  platforms like LeetCode, HackerRank, and GeeksforGeeks, focusing on medium to hard problems.                   │
# │  *   **Strong Language Proficiency:** Choose one programming language (Java, Python, or C++) and achieve        │
# │  expert-level proficiency, including advanced features, OOPS concepts, and standard libraries.                  │
# │  *   **Build Real-World Projects:** Develop 2-3 substantial projects (e.g., full-stack web application, ML      │
# │  model, cloud-native application) that demonstrate practical application of skills and technologies.            │
# │  *   **Solidify Core CS Fundamentals:** Thoroughly revise Operating Systems, DBMS (with SQL querying),          │
# │  Object-Oriented Programming (OOPs) concepts, and Computer Networks.                                            │
# │  *   **Practice Mock Interviews:** Engage in mock technical and HR interviews to refine communication skills,   │
# │  articulate your thought process for coding problems, and present projects effectively.                         │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: Research TCS Digital placement preparation for B.Tech students. Include hiring process, technical        │
# │  stack, eligibility, recent hiring trends, and preparation tips. Give 3-5 bullets per section.                  │
# │  Agent: Placement Researcher                                                                                    │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Using the research notes, produce a 1-page placement brief for B.Tech students. Use markdown format.     │
# │  Include a 3-line opening hook, 5 clear sections, and a 3-line closing call-to-action.                          │
# │  ID: 98f53de0-77ff-4d64-acc7-3f2090589f6b                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Brief Writer                                                                                  │
# │                                                                                                                 │
# │  Task: Using the research notes, produce a 1-page placement brief for B.Tech students. Use markdown format.     │
# │  Include a 3-line opening hook, 5 clear sections, and a 3-line closing call-to-action.                          │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [Finalize] todos_count=0, todos_with_results=0
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Brief Writer                                                                                  │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  # TCS Digital — Placement Prep Brief                                                                           │
# │                                                                                                                 │
# │  Dreaming of a career that challenges you, rewards innovation, and places you at the forefront of technology?   │
# │  TCS Digital offers elite opportunities for B.Tech graduates ready to dive deep into advanced tech roles with   │
# │  significantly higher compensation and growth. Prepare to showcase your expertise and problem-solving prowess!  │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### 1. The Hiring Journey                                                                                      │
# │                                                                                                                 │
# │  *   **Online Assessment:** Expect a rigorous test covering verbal, logical, numerical ability, and *advanced   │
# │  coding*. The coding section is notably tougher than for TCS Ninja, demanding strong problem-solving skills.    │
# │  *   **Technical Interview:** This is a deep dive into **Data Structures & Algorithms (DSA)**, core CS          │
# │  concepts (OS, DBMS, OOPS, CN), your chosen programming language, and extensive discussion on your projects.    │
# │  Be ready to articulate your thought process.                                                                   │
# │  *   **Managerial Interview (Often Combined):** May assess your leadership potential, ability to handle         │
# │  complex scenarios, and technical vision.                                                                       │
# │  *   **HR Interview:** Standard questions to assess cultural fit, communication skills, and verify your         │
# │  background and expectations.                                                                                   │
# │                                                                                                                 │
# │  ### 2. Essential Technical Stack                                                                               │
# │                                                                                                                 │
# │  Mastery in these areas is crucial for TCS Digital:                                                             │
# │                                                                                                                 │
# │  *   **Core Programming:** Expert-level proficiency in Java, Python, or C++ with a robust understanding of      │
# │  OOPS principles.                                                                                               │
# │  *   **Data Structures & Algorithms (DSA):** Non-negotiable for tackling complex problems.                      │
# │  *   **Database Management:** Strong command of SQL (e.g., MySQL, PostgreSQL) and familiarity with NoSQL        │
# │  concepts.                                                                                                      │
# │  *   **Web Technologies (Advantage):** Experience with front-end (React, Angular) or back-end frameworks        │
# │  (Spring Boot, Django, Flask) is highly valued.                                                                 │
# │  *   **Cloud/DevOps Concepts (Advantage):** Exposure to AWS, Azure, GCP, CI/CD, microservices, Docker, or       │
# │  Kubernetes will give you an edge.                                                                              │
# │                                                                                                                 │
# │  ### 3. Eligibility Criteria                                                                                    │
# │                                                                                                                 │
# │  *   **Degree:** B.E./B.Tech from all engineering disciplines, with a strong preference for CS, IT, ECE, EEE.   │
# │  *   **Academic Performance:** Consistent academic record required—typically 60% or 6.0 CGPA throughout 10th,   │
# │  12th, and B.Tech.                                                                                              │
# │  *   **Backlogs:** Generally, no active backlogs are permitted at the time of appearing or joining.             │
# │  *   **Education Gap:** A maximum of 1-2 years gap in education is usually allowed for freshers, with no prior  │
# │  work experience.                                                                                               │
# │                                                                                                                 │
# │  ### 4. Key Hiring Trends                                                                                       │
# │                                                                                                                 │
# │  *   **Niche Skills are Gold:** High demand for expertise in AI/ML, Data Science, Cloud Computing,              │
# │  Cybersecurity, and IoT.                                                                                        │
# │  *   **Practical Coding & Projects:** Theoretical knowledge isn't enough; recruiters emphasize demonstrable     │
# │  coding ability and impactful, real-world projects.                                                             │
# │  *   **Problem-Solving Acumen:** Your ability to analyze complex problems, think critically, and structure      │
# │  solutions is paramount.                                                                                        │
# │  *   **Higher Compensation:** TCS Digital offers significantly better packages than TCS Ninja, reflecting the   │
# │  demand for specialized, high-skill talent.                                                                     │
# │                                                                                                                 │
# │  ### 5. Your Preparation Strategy                                                                               │
# │                                                                                                                 │
# │  *   **Master DSA & Coding:** Dedicate substantial time to platforms like LeetCode, HackerRank, GeeksforGeeks.  │
# │  Target medium to hard problems consistently.                                                                   │
# │  *   **Strong Language Proficiency:** Become an expert in one language (Java, Python, C++), including its       │
# │  advanced features and standard libraries.                                                                      │
# │  *   **Build Real-World Projects:** Develop 2-3 substantial projects (e.g., full-stack app, ML model, cloud     │
# │  service) that showcase practical skill application.                                                            │
# │  *   **Solidify Core CS Fundamentals:** Thoroughly revise OS, DBMS (including SQL queries), OOPs concepts, and  │
# │  Computer Networks.                                                                                             │
# │  *   **Practice Mock Interviews:** Engage in mock technical and HR interviews to refine communication,          │
# │  articulate your problem-solving approach, and present projects effectively.                                    │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  TCS Digital is your gateway to a challenging and rewarding tech career. With focused effort and smart          │
# │  preparation, you can unlock this high-value opportunity. Start preparing diligently now – your future self     │
# │  will thank you!                                                                                                │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: Using the research notes, produce a 1-page placement brief for B.Tech students. Use markdown format.     │
# │  Include a 3-line opening hook, 5 clear sections, and a 3-line closing call-to-action.                          │
# │  Agent: Placement Brief Writer                                                                                  │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# === FINAL OUTPUT ===
#
# # TCS Digital — Placement Prep Brief
#
# Dreaming of a career that challenges you, rewards innovation, and places you at the forefront of technology? TCS Digital offers elite opportunities for B.Tech graduates ready to dive deep into advanced tech roles with significantly higher compensation and growth. Prepare to showcase your expertise and problem-solving prowess!
#
# ---
#
# ### 1. The Hiring Journey
#
# *   **Online Assessment:** Expect a rigorous test covering verbal, logical, numerical ability, and *advanced coding*. The coding section is notably tougher than for TCS Ninja, demanding strong problem-solving skills.
# *   **Technical Interview:** This is a deep dive into **Data Structures & Algorithms (DSA)**, core CS concepts (OS, DBMS, OOPS, CN), your chosen programming language, and extensive discussion on your projects. Be ready to articulate your thought process.
# *   **Managerial Interview (Often Combined):** May assess your leadership potential, ability to handle complex scenarios, and technical vision.
# *   **HR Interview:** Standard questions to assess cultural fit, communication skills, and verify your background and expectations.
#
# ### 2. Essential Technical Stack
#
# Mastery in these areas is crucial for TCS Digital:
#
# *   **Core Programming:** Expert-level proficiency in Java, Python, or C++ with a robust understanding of OOPS principles.
# *   **Data Structures & Algorithms (DSA):** Non-negotiable for tackling complex problems.
# *   **Database Management:** Strong command of SQL (e.g., MySQL, PostgreSQL) and familiarity with NoSQL concepts.
# *   **Web Technologies (Advantage):** Experience with front-end (React, Angular) or back-end frameworks (Spring Boot, Django, Flask) is highly valued.
# *   **Cloud/DevOps Concepts (Advantage):** Exposure to AWS, Azure, GCP, CI/CD, microservices, Docker, or Kubernetes will give you an edge.
#
# ### 3. Eligibility Criteria
#
# *   **Degree:** B.E./B.Tech from all engineering disciplines, with a strong preference for CS, IT, ECE, EEE.
# *   **Academic Performance:** Consistent academic record required—typically 60% or 6.0 CGPA throughout 10th, 12th, and B.Tech.
# *   **Backlogs:** Generally, no active backlogs are permitted at the time of appearing or joining.
# *   **Education Gap:** A maximum of 1-2 years gap in education is usually allowed for freshers, with no prior work experience.
#
# ### 4. Key Hiring Trends
#
# *   **Niche Skills are Gold:** High demand for expertise in AI/ML, Data Science, Cloud Computing, Cybersecurity, and IoT.
# *   **Practical Coding & Projects:** Theoretical knowledge isn't enough; recruiters emphasize demonstrable coding ability and impactful, real-world projects.
# *   **Problem-Solving Acumen:** Your ability to analyze complex problems, think critically, and structure solutions is paramount.
# *   **Higher Compensation:** TCS Digital offers significantly better packages than TCS Ninja, reflecting the demand for specialized, high-skill talent.
#
# ### 5. Your Preparation Strategy
#
# *   **Master DSA & Coding:** Dedicate substantial time to platforms like LeetCode, HackerRank, GeeksforGeeks. Target medium to hard problems consistently.
# *   **Strong Language Proficiency:** Become an expert in one language (Java, Python, C++), including its advanced features and standard libraries.
# *   **Build Real-World Projects:** Develop 2-3 substantial projects (e.g., full-stack app, ML model, cloud service) that showcase practical skill application.
# *   **Solidify Core CS Fundamentals:** Thoroughly revise OS, DBMS (including SQL queries), OOPs concepts, and Computer Networks.
# *   **Practice Mock Interviews:** Engage in mock technical and HR interviews to refine communication, articulate your problem-solving approach, and present projects effectively.
#
# ---
#
# TCS Digital is your gateway to a challenging and rewarding tech career. With focused effort and smart preparation, you can unlock this high-value opportunity. Start preparing diligently now – your future self will thank you!
# ╭──────────────────────────────────────────────── Crew Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Completed                                                                                       │
# │  Name: crew                                                                                                     │
# │  ID: 209563b7-2543-489e-b6d8-85f8c55cc9db                                                                       │
# │  Final Output: # TCS Digital — Placement Prep Brief                                                             │
# │                                                                                                                 │
# │  Dreaming of a career that challenges you, rewards innovation, and places you at the forefront of technology?   │
# │  TCS Digital offers elite opportunities for B.Tech graduates ready to dive deep into advanced tech roles with   │
# │  significantly higher compensation and growth. Prepare to showcase your expertise and problem-solving prowess!  │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### 1. The Hiring Journey                                                                                      │
# │                                                                                                                 │
# │  *   **Online Assessment:** Expect a rigorous test covering verbal, logical, numerical ability, and *advanced   │
# │  coding*. The coding section is notably tougher than for TCS Ninja, demanding strong problem-solving skills.    │
# │  *   **Technical Interview:** This is a deep dive into **Data Structures & Algorithms (DSA)**, core CS          │
# │  concepts (OS, DBMS, OOPS, CN), your chosen programming language, and extensive discussion on your projects.    │
# │  Be ready to articulate your thought process.                                                                   │
# │  *   **Managerial Interview (Often Combined):** May assess your leadership potential, ability to handle         │
# │  complex scenarios, and technical vision.                                                                       │
# │  *   **HR Interview:** Standard questions to assess cultural fit, communication skills, and verify your         │
# │  background and expectations.                                                                                   │
# │                                                                                                                 │
# │  ### 2. Essential Technical Stack                                                                               │
# │                                                                                                                 │
# │  Mastery in these areas is crucial for TCS Digital:                                                             │
# │                                                                                                                 │
# │  *   **Core Programming:** Expert-level proficiency in Java, Python, or C++ with a robust understanding of      │
# │  OOPS principles.                                                                                               │
# │  *   **Data Structures & Algorithms (DSA):** Non-negotiable for tackling complex problems.                      │
# │  *   **Database Management:** Strong command of SQL (e.g., MySQL, PostgreSQL) and familiarity with NoSQL        │
# │  concepts.                                                                                                      │
# │  *   **Web Technologies (Advantage):** Experience with front-end (React, Angular) or back-end frameworks        │
# │  (Spring Boot, Django, Flask) is highly valued.                                                                 │
# │  *   **Cloud/DevOps Concepts (Advantage):** Exposure to AWS, Azure, GCP, CI/CD, microservices, Docker, or       │
# │  Kubernetes will give you an edge.                                                                              │
# │                                                                                                                 │
# │  ### 3. Eligibility Criteria                                                                                    │
# │                                                                                                                 │
# │  *   **Degree:** B.E./B.Tech from all engineering disciplines, with a strong preference for CS, IT, ECE, EEE.   │
# │  *   **Academic Performance:** Consistent academic record required—typically 60% or 6.0 CGPA throughout 10th,   │
# │  12th, and B.Tech.                                                                                              │
# │  *   **Backlogs:** Generally, no active backlogs are permitted at the time of appearing or joining.             │
# │  *   **Education Gap:** A maximum of 1-2 years gap in education is usually allowed for freshers, with no prior  │
# │  work experience.                                                                                               │
# │                                                                                                                 │
# │  ### 4. Key Hiring Trends                                                                                       │
# │                                                                                                                 │
# │  *   **Niche Skills are Gold:** High demand for expertise in AI/ML, Data Science, Cloud Computing,              │
# │  Cybersecurity, and IoT.                                                                                        │
# │  *   **Practical Coding & Projects:** Theoretical knowledge isn't enough; recruiters emphasize demonstrable     │
# │  coding ability and impactful, real-world projects.                                                             │
# │  *   **Problem-Solving Acumen:** Your ability to analyze complex problems, think critically, and structure      │
# │  solutions is paramount.                                                                                        │
# │  *   **Higher Compensation:** TCS Digital offers significantly better packages than TCS Ninja, reflecting the   │
# │  demand for specialized, high-skill talent.                                                                     │
# │                                                                                                                 │
# │  ### 5. Your Preparation Strategy                                                                               │
# │                                                                                                                 │
# │  *   **Master DSA & Coding:** Dedicate substantial time to platforms like LeetCode, HackerRank, GeeksforGeeks.  │
# │  Target medium to hard problems consistently.                                                                   │
# │  *   **Strong Language Proficiency:** Become an expert in one language (Java, Python, C++), including its       │
# │  advanced features and standard libraries.                                                                      │
# │  *   **Build Real-World Projects:** Develop 2-3 substantial projects (e.g., full-stack app, ML model, cloud     │
# │  service) that showcase practical skill application.                                                            │
# │  *   **Solidify Core CS Fundamentals:** Thoroughly revise OS, DBMS (including SQL queries), OOPs concepts, and  │
# │  Computer Networks.                                                                                             │
# │  *   **Practice Mock Interviews:** Engage in mock technical and HR interviews to refine communication,          │
# │  articulate your problem-solving approach, and present projects effectively.                                    │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  TCS Digital is your gateway to a challenging and rewarding tech career. With focused effort and smart          │
# │  preparation, you can unlock this high-value opportunity. Start preparing diligently now – your future self     │
# │  will thank you!                                                                                                │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %%
import pathlib

pathlib.Path("day10_lab10a_transcript.txt").write_text(str(result))

print("Saved: day10_lab10a_transcript.txt")
print("Characters:", len(str(result)))
# Out:
# Saved: day10_lab10a_transcript.txt
# Characters: 3965

# %%
try:
    for i, output in enumerate(result.tasks_output):
        print(f"\n=== Task {i+1} Output ===")
        print(str(output)[:800])
except Exception:
    print("Task outputs not available in this CrewAI version.")
    print("Final result saved successfully.")
# Out:
# === Task 1 Output ===
# Here is a factual placement brief for TCS Digital preparation for B.Tech students:
#
# ### Hiring Process
#
# *   **Online Assessment:** Consists of verbal ability, logical reasoning, numerical ability, and advanced coding sections. The coding challenge is significantly more difficult than for TCS Ninja.
# *   **Technical Interview:** Focuses on in-depth Data Structures & Algorithms (DSA), core CS concepts (Operating Systems, DBMS, OOPS, Computer Networks), chosen programming language proficiency, and detailed discussion of projects. Problem-solving skills are critically evaluated.
# *   **Managerial Interview (Optional/Combined):** May assess situational judgment, leadership potential, and technical vision relevant to complex project scenarios, often combined with the technical round.
# *   **HR Inte
#
# === Task 2 Output ===
# # TCS Digital — Placement Prep Brief
#
# Dreaming of a career that challenges you, rewards innovation, and places you at the forefront of technology? TCS Digital offers elite opportunities for B.Tech graduates ready to dive deep into advanced tech roles with significantly higher compensation and growth. Prepare to showcase your expertise and problem-solving prowess!
#
# ---
#
# ### 1. The Hiring Journey
#
# *   **Online Assessment:** Expect a rigorous test covering verbal, logical, numerical ability, and *advanced coding*. The coding section is notably tougher than for TCS Ninja, demanding strong problem-solving skills.
# *   **Technical Interview:** This is a deep dive into **Data Structures & Algorithms (DSA)**, core CS concepts (OS, DBMS, OOPS, CN), your chosen programming language, and extensive dis

# %%
markdown_content = str(result)

with open("tcs_digital_brief.md", "w", encoding="utf-8") as f:
    f.write(markdown_content)

print("Markdown file created successfully: tcs_digital_brief.md")
# Out:
# Markdown file created successfully: tcs_digital_brief.md

# %%
from google.colab import files

files.download("tcs_digital_brief.md")

# %%
with open("tcs_digital_brief.md", "r", encoding="utf-8") as f:
    print(f.read()[:2000])
# Out:
# # TCS Digital — Placement Prep Brief
#
# Dreaming of a career that challenges you, rewards innovation, and places you at the forefront of technology? TCS Digital offers elite opportunities for B.Tech graduates ready to dive deep into advanced tech roles with significantly higher compensation and growth. Prepare to showcase your expertise and problem-solving prowess!
#
# ---
#
# ### 1. The Hiring Journey
#
# *   **Online Assessment:** Expect a rigorous test covering verbal, logical, numerical ability, and *advanced coding*. The coding section is notably tougher than for TCS Ninja, demanding strong problem-solving skills.
# *   **Technical Interview:** This is a deep dive into **Data Structures & Algorithms (DSA)**, core CS concepts (OS, DBMS, OOPS, CN), your chosen programming language, and extensive discussion on your projects. Be ready to articulate your thought process.
# *   **Managerial Interview (Often Combined):** May assess your leadership potential, ability to handle complex scenarios, and technical vision.
# *   **HR Interview:** Standard questions to assess cultural fit, communication skills, and verify your background and expectations.
#
# ### 2. Essential Technical Stack
#
# Mastery in these areas is crucial for TCS Digital:
#
# *   **Core Programming:** Expert-level proficiency in Java, Python, or C++ with a robust understanding of OOPS principles.
# *   **Data Structures & Algorithms (DSA):** Non-negotiable for tackling complex problems.
# *   **Database Management:** Strong command of SQL (e.g., MySQL, PostgreSQL) and familiarity with NoSQL concepts.
# *   **Web Technologies (Advantage):** Experience with front-end (React, Angular) or back-end frameworks (Spring Boot, Django, Flask) is highly valued.
# *   **Cloud/DevOps Concepts (Advantage):** Exposure to AWS, Azure, GCP, CI/CD, microservices, Docker, or Kubernetes will give you an edge.
#
# ### 3. Eligibility Criteria
#
# *   **Degree:** B.E./B.Tech from all engineering disciplines, with a strong preference for CS, IT, ECE, EEE.
# *   **Acad
